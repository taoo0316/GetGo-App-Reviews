# %%
import pandas as pd
import numpy as np
import json

from app_store_scraper import AppStore
getgo = AppStore(country='sg', app_name='getgo', app_id = '1545316216')

getgo.review(how_many=2000)
# Out:
# 2023-02-24 14:31:49,231 [INFO] Base - Initialised: AppStore('sg', 'getgo', 1545316216)
# 2023-02-24 14:31:49,231 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/getgo/id1545316216
# 2023-02-24 14:31:54,289 [INFO] Base - [id:1545316216] Fetched 460 reviews (460 fetched in total)
# 2023-02-24 14:31:56,131 [INFO] Base - [id:1545316216] Fetched 616 reviews (616 fetched in total)

# %%
getgo.reviews[:10]
# Out:
# [{'date': datetime.datetime(2021, 10, 29, 2, 42, 14),
#   'developerResponse': {'id': 26048957,
#    'body': "Hey Gracias, thank you for your review! We really appreciate your support and we are so glad you are enjoying our service. 😊 We will definitely take note of your feedback and take it into consideration as we continue to improve on our service! We can't wait to see you continue to enjoy the #FreedomToDrive with us. 🥰\n\nCheers, Natalie",
#    'modified': '2021-11-03T06:03:49Z'},
#   'review': 'Good point A to point A rental service with no membership fees! The app interface is very intuitive and easy to use although there are some issues connecting to the car to unlock them at times depending on the connection. \n\nAlso, because the rental return is based on the app, essential to make sure your phone as enough battery. The fleets are well maintained, clean and available at many convenient locations. Save $, Don’t need to buy car. :)\n\nSome areas to improve on will be the chat function - to keep the chat pop up available for access through the entire app instead of having to click into certain options - which can be quite jarring if the user is in need of help urgently.',
#   'rating': 4,
#   'isEdited': False,
#   'userName': 'Gracias.i.m',
#   'title': 'Convenient rental service, Easy to use app interface'},
#  {'date': datetime.datetime(2022, 1, 28, 7, 52, 22),
#   'developerResponse': {'id': 27222908,
#    'body': "Hey Vishal, thanks for leaving us a review! We'll definitely take note of your feedback and work on improving our service to bring you a better GetGo experience. Hope you continue to enjoy the #FreedomToDrive with us! 🙌",
#    'modified': '2022-01-28T07:52:22Z'},
#   'review': 'Today booked Ssangyong XLV with GetGo Carsharing, I always loved the car and it was a smooth ride today to City Square mall, But the issue is with GetGo Mobile Application, Basement Parking of City Square mall has no Mobile data ( Not sure whether due to my M1 eSim ), But GetGo Application is doing Api calls to its Backend to fetch data during app initialization, since no internet the app stuck at first GetGo design page, I had to enter the mall to access Mall Wifi and then open the app then open the booking, Then come back to car park and finally i could connect to car via bluetooth! And Lock Phew! GetGo team,  Kind request (I made the same via Live chat too), When an user books any car, Please make current booking ( to connect to car ) to be available in offline, Also make this booking available even before doing all your api call at app initialization! That way connecting to car from place without intenet will be a breeze! Giving 5 Star anyways for their efforts!!!',
#   'rating': 5,
#   'isEdited': True,
#   'userName': 'Vishal C B',
#   'title': 'Need to Access current Booking via Offline (To connect to Car)'},
#  {'date': datetime.datetime(2021, 12, 4, 2, 47, 8),
#   'developerResponse': {'id': 26796019,
#    'body': "Hey Lexus, thank you so much for the awesome review! We really appreciate it, and we're so glad to hear that you've been enjoying our service. Hope you'll continue to enjoy the #FreedomToDrive with us! 😉  – Ella",
#    'modified': '2021-12-13T08:57:25Z'},
#   'review': 'GetGO had a strong community at a certain platform for us to share all the good better best problems and solutions. All are very responsive and nice. Best part? NO MEMBERSHIP FEE! Have their own ESSO card to top up once need to pump and you know what’s the best? It’s part of the rental fee. Nothing exclusive no hidden charge. And the super best best BEST is…. In front of my house is the area where the GETGO is. So it’s very super convenient for me. These are the 3 best for my perspective. I can’t think of anything 4th best. Unless you think GetGO will make their car fly 🤣🤣🤣🤣🤣 just kidding. They’re growing n growing. FYI GETGO, this is my first time writing app review. I find it useless and no time for that. But?!? You guys really worth my time seriously. Last but not least, thanks GETGO for letting me dreams come true, your time, effort, all the hard work, blood sweat tears and everything….. BIG THANK YOU 😊',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'Lexus Guo',
#   'title': 'it’s nothing but a PERFECT APP'},
#  {'date': datetime.datetime(2021, 12, 8, 2, 23, 32),
#   'developerResponse': {'id': 26796398,
#    'body': "Hey gogetclean, thanks for sharing your feedback with us — we apologise for the experience you faced and we'll definitely take note of this as we continue to improve on our service. In future, you can also report this to our Support Team via Live Chat on the app or on help.getgo.sg. 💪  – Ella",
#    'modified': '2021-12-13T09:08:57Z'},
#   'review': 'Hi i would like to reflect on the cleanliness issues. Sadly on top of bump and scratches which I understand we could not help much. But please be responsible on cleaning the car after use. Or GETGO why the company not getting someone vacuum and wash the car? Some of your car already infested cockroaches. That is because of irresponsible users. The worse experience was i took stavic last minute which i could not cancel. It was at cassia cres. The car is full of animal fur and dripping and wipes of saliva over the window screen and gearstick. Worse the gearstick is being bite!!! I have to pay for car wash n vacuum because im a muslim and i have 2 babies. This is car sharing. So idiot user please open up your brain and be responsible. It not your FATHER car! So Getgo please take action on them and implement a better rules…….',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'gogetclean',
#   'title': 'Responsibility of hirer.'},
#  {'date': datetime.datetime(2023, 2, 22, 15, 45, 44),
#   'developerResponse': {'id': 35044471,
#    'body': 'Hi there, thank you for taking the time to write a review. It’s reviews like this that help us identify areas for improvement. We would like to reassure you that user experience is very important to us at GetGo. Should you face a similar situation in the future, please do not hesitate to contact our Live Chat via help.getgo.sg. If you have any other feedback, please email us at hello@getgo.sg — we’re here to listen and do better. \n',
#    'modified': '2023-02-24T01:40:11Z'},
#   'review': 'Two times I encountered the app jammed while ongoing rental services on a separate occasion. Had a hard time trying to find ways to contact help services which is useless because there is no contact number. I googled and there is no help I can find. I was logged out many times and I had to delete app couple of times hoping it will reset again. VERY FRUSTRATING! \nTwice it took me more than 45mins to eventually get it working automatically. Bug issue? I dunno. But I have to extend my time because it disrupts my errands time. \nI really really hope getgo have a call center or helpline. Because even if I want to raised an issue through the app, it is useless because the app doesn’t work when that happens. \nNow everytime I rent a car, I always hoped this app issues doesn’t happen because all I can do is wait for it to be ok by itself.',
#   'rating': 3,
#   'isEdited': False,
#   'userName': 'GETGO USER',
#   'title': 'APP SOMETIMES HAVE ISSUES'},
#  {'date': datetime.datetime(2022, 3, 10, 10, 30, 15),
#   'review': 'I joined GetGo in February 2021, when they first launched. I have to say the app is pretty much easy to use and intuitive - just a few taps and you’re good to go! Customer service team is responsive (they use a “live-chat” function) and they’ve been very helpful in all the times I needed some help. \n\nThe cars - when I first joined in Feb 2021, there’s only the Mazda 3 and Toyota Sienta. Today, there’s more than 15 different types of vehicles located all over the island. So that’s really good! \n\nCar cleanliness? Not an issue as the residents in my estate seem to take care of the cars well. Of course, you can always drop them a feedback if you happen to chance upon a dirty car. \n\nTo me, car-sharing is an alternative to public transport and those of Grab and taxis. For future GetGoers, give it a try and treat the cars as if they’re your own. But do also be realistic that like all car-sharing platforms, the cars may sometimes not be in their best condition because of inconsiderate users. The option is always there to speak with the live chat agent if you encounter an unpleasant car :)',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'kelv99',
#   'title': 'Easy to use app, fantastic customer service team and wide variety of cars'},
#  {'date': datetime.datetime(2022, 3, 11, 11, 31, 20),
#   'developerResponse': {'id': 28574280,
#    'body': 'Thank you so much for sharing your experience! We hope you continue to enjoy the #FreedomToDrive with us. ',
#    'modified': '2022-03-15T02:46:14Z'},
#   'review': 'It was early morning, when to the seaside, however, the rain started..doing nothing but just waiting..n when the rain slow down, wanted to continue with the journey, but the HP don’t show any data, failed to unlock the vehicle..after that, trying to get some free wifi so could contact operator for help..after a few miles of walking, then came to a restaurant, lucky to have free wifi access. Immediately contact the operator, and they are so kind to assist, make sure you provide the right booking number and vehicle number. So they got the right vehicle to unlock.\n\nThanks n feeling grateful!',
#   'rating': 4,
#   'isEdited': False,
#   'userName': 'Good play or play good',
#   'title': 'Out of data HP malfunction'},
#  {'date': datetime.datetime(2022, 3, 13, 2, 11, 8),
#   'developerResponse': {'id': 28574685,
#    'body': 'Hey there, thank you so much for the awesome and detailed review! We really appreciate it. 🤩',
#    'modified': '2022-03-15T03:20:31Z'},
#   'review': 'One of the best car sharing platforms out there with affordable, reasonable and competitive prices considering the car models/categories, accessibility and vast number of locations.\n\nSimple, straightforward booking and registration process. Although app design/interface/user experiences can be improved to allow for a smoother experience and reducing the bugs.\n\nPricing structure and layout is easy to follow. No deposits, membership or anything that ties you in👍. \n\nWebsite is easy to navigate, with the necessary information provided clearly (QnA), with most usual questions asked abouts the booking process shown.\n\nCustomer service/ live chat is available as well.\n\nCars are clean, of decent quality, well-maintained regularly. Best part is zero concerns for paying fuel. Perks including being able to extend during booking, with additional 15mins booking time before and 10 mins after booking ends.\n\nOne suggestion that i and most people also look forward to is the implementation of A-B process. It will be a game changer for the platform, being the first to have it amongst other competitors other than bluesg.',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'ksze97',
#   'title': 'Fuss free car rental'},
#  {'date': datetime.datetime(2021, 12, 3, 13, 43, 39),
#   'developerResponse': {'id': 26795877,
#    'body': "Hey mbsalcedo, thank you so much for sharing your feedback! We'll definitely take note of them as we're constantly looking to improve on our service. We hope you'll continue to enjoy the #FreedomToDrive with us! ☺️  –\xa0Ella",
#    'modified': '2021-12-13T08:53:38Z'},
#   'review': 'Brillintly organized company! Hassle free registration, fast and easy booking, well designed app, and prompt action on critical issues 👍👍👍. Areas of improvement: 1. More frequent car cleaning service especially for cars that are frequently used. (Alternative is to provide incentive programs for users who will take the car for a wash. Similar to how users are rewarded for topping up petrol). 2. Regular maintenance check on cars. There are cars the requires replacement on parts such as the rubber on wiper blades, lightbulb on tailights. This has been reported but no replacement has been made yet. 3. On board camera sd car is always full and the camera autoshuts off.',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'mbsalcedo',
#   'title': 'Great Customer Service!'},
#  {'date': datetime.datetime(2022, 11, 18, 13, 46, 31),
#   'review': 'I faced the exact same issue as a previous reviewer recently of being accused of causing damages to the car, even though I have absolute confidence that it was not caused by me as well. In fact, I only booked the car for an hour to travel nearby. Getgo’s ridiculous T&C states that if a user lodged a report regarding car damage, and if the previous user does not have photographic evidence to prove that it is not caused by him/her, they will be liable for the repair charges. The most suspicious thing was, throughout my entire email exchange with the staff, he did not even send me a pic of the alleged damages at all and yet kept requesting for photographic evidence from me. Will be making a police report regarding my case as well. Be warned about using GetGo as a car sharing option as you may face the same situation as me too.',
#   'rating': 1,
#   'isEdited': False,
#   'userName': 'lingz99',
#   'title': 'Accused of False Charges'}]

# %%
getgodf = pd.DataFrame(np.array(getgo.reviews),columns=['review'])
getgodf2 = getgodf.join(pd.DataFrame(getgodf.pop('review').tolist()))
getgodf2.head()
# Out:
#                  date                                  developerResponse  \
# 0 2021-10-29 02:42:14  {'id': 26048957, 'body': 'Hey Gracias, thank y...
# 1 2022-01-28 07:52:22  {'id': 27222908, 'body': 'Hey Vishal, thanks f...
# 2 2021-12-04 02:47:08  {'id': 26796019, 'body': 'Hey Lexus, thank you...
# 3 2021-12-08 02:23:32  {'id': 26796398, 'body': 'Hey gogetclean, than...
# 4 2023-02-22 15:45:44  {'id': 35044471, 'body': 'Hi there, thank you ...
#
#                                               review  rating  isEdited  \
# 0  Good point A to point A rental service with no...       4     False
# 1  Today booked Ssangyong XLV with GetGo Carshari...       5      True
# 2  GetGO had a strong community at a certain plat...       5     False
# 3  Hi i would like to reflect on the cleanliness ...       5     False
# 4  Two times I encountered the app jammed while o...       3     False
#
#       userName                                              title
# 0  Gracias.i.m  Convenient rental service, Easy to use app int...
# 1   Vishal C B  Need to Access current Booking via Offline (To...
# 2    Lexus Guo                     it’s nothing but a PERFECT APP
# 3   gogetclean                           Responsibility of hirer.
# 4   GETGO USER                          APP SOMETIMES HAVE ISSUES

# %%
getgodf2.to_csv("getgo.csv")

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt


# create a word cloud from the review column
text = ' '.join(getgodf2['review'].astype(str))
wordcloud = WordCloud(width=800, height=400, stopwords=STOPWORDS).generate(text)

# plot the word cloud
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordcloud.to_file('wordcloudreview.png')

# %%
# create a word cloud from the review column
text = ' '.join(getgodf2['title'].astype(str))
wordcloud = WordCloud(width=800, height=400, stopwords=STOPWORDS).generate(text)

# plot the word cloud
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordcloud.to_file('wordcloudtitle.png')

# %%
# create a histogram of the rating column
plt.hist(getgodf2['rating'], bins=5)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
# create a box plot of the rating column
plt.boxplot(getgodf2['rating'])
plt.xlabel('Rating')
plt.show()

# %%
# convert the date column to a datetime format
getgodf2['date'] = pd.to_datetime(getgodf2['date'], format='%Y-%m-%d %H:%M:%S')

# create a scatter plot of rating vs date
plt.scatter(getgodf2['date'], getgodf2['rating'])
plt.xlabel('Date')
plt.ylabel('Rating')
plt.show()

# %%
from scipy import stats

# create a scatter plot of rating vs date
plt.scatter(getgodf2['date'], getgodf2['rating'])

# add a linear trendline to the scatter plot
slope, intercept, r_value, p_value, std_err = stats.linregress(getgodf2['date'].astype(int), getgodf2['rating'])
line = slope*getgodf2['date'].astype(int) + intercept
plt.plot(getgodf2['date'], line, color='red')

plt.xlabel('Date')
plt.ylabel('Rating')
plt.show()

# %%
# group the data by month and calculate the mean rating
df_monthly = getgodf2.groupby(pd.Grouper(key='date', freq='M'))['rating'].mean().reset_index()

# create a line chart of the monthly average rating
plt.plot(df_monthly['date'], df_monthly['rating'])
plt.xlabel('Date')
plt.ylabel('Average rating')
plt.show()

# %%
# select the rows where the rating is 1
df_rating_1 = getgodf2[getgodf2['rating'] == 1]

df_rating_1['review'].head(10)
# Out:
# 9      I faced the exact same issue as a previous rev...
# 18     If you are a thrill seeker and like surprises,...
# 36     App crashes with errors, no way around but rei...
# 38     I booked for an hour but I didn’t turn up to u...
# 39     Very poor and disappointing customer service o...
# 58     Great idea - fantastic for the sharing economy...
# 62     Having a car booked, system or admin doesn’t i...
# 83     Don't forgo your car for community ones just y...
# 87     This is my first time using this service and i...
# 112    Whenever I launched the app or tap anywhere it...
# Name: review, dtype: object

# %%
# create a word cloud from the review column
text = ' '.join(df_rating_1['review'].astype(str))
wordcloud = WordCloud(width=800, height=400, stopwords=STOPWORDS).generate(text)

# plot the word cloud
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordcloud.to_file('wordcloudrating1.png')

# %%
df_monthly
# Out:
#          date    rating
# 0  2021-02-28  2.000000
# 1  2021-03-31  1.000000
# 2  2021-04-30  2.500000
# 3  2021-05-31  3.625000
# 4  2021-06-30  5.000000
# 5  2021-07-31  2.000000
# 6  2021-08-31  4.428571
# 7  2021-09-30  3.200000
# 8  2021-10-31  2.818182
# 9  2021-11-30  2.000000
# 10 2021-12-31  3.772727
# 11 2022-01-31  2.800000
# 12 2022-02-28  2.750000
# 13 2022-03-31  4.605114
# 14 2022-04-30  3.555556
# 15 2022-05-31  1.611111
# 16 2022-06-30  1.625000
# 17 2022-07-31  2.562500
# 18 2022-08-31  2.750000
# 19 2022-09-30  2.333333
# 20 2022-10-31  2.666667
# 21 2022-11-30  2.571429
# 22 2022-12-31  2.142857
# 23 2023-01-31  2.285714
# 24 2023-02-28  2.500000

# %%
from statsmodels.tsa.arima.model import ARIMA

# fit an ARIMA model to the average rating per month
model = ARIMA(df_monthly['rating'], order=(1,1,1))
model_fit = model.fit()

# use the model to make a one-step forecast for the next month
forecast = model_fit.forecast()

# print the forecasted average rating for the next month
print(forecast)
# Out:
# 25    2.706629
# dtype: float64

# %%
df_rating_1
# Out:
#                    date                                  developerResponse  \
# 9   2022-11-18 13:46:31                                                NaN
# 18  2022-04-18 21:53:38                                                NaN
# 36  2022-02-04 10:34:48  {'id': 27916461, 'body': 'Hey Gary, thanks for...
# 38  2022-02-13 10:40:27  {'id': 28253932, 'body': 'Hey Enzaiizi, we're ...
# 39  2023-01-08 07:39:14  {'id': 34924803, 'body': 'Hi there, thank you ...
# ..                  ...                                                ...
# 598 2022-11-11 08:40:14  {'id': 34959264, 'body': 'Hi there, thank you ...
# 601 2022-10-04 10:26:02                                                NaN
# 606 2022-03-17 09:29:12  {'id': 28712062, 'body': 'Hey Ifan, we're so s...
# 614 2021-11-01 04:17:07  {'id': 26048867, 'body': 'Hey Ohhl, we're so s...
# 615 2021-05-17 04:04:44  {'id': 23521519, 'body': 'Hey Shagembeng, than...
#
#                                                 review  rating  isEdited  \
# 9    I faced the exact same issue as a previous rev...       1     False
# 18   If you are a thrill seeker and like surprises,...       1     False
# 36   App crashes with errors, no way around but rei...       1     False
# 38   I booked for an hour but I didn’t turn up to u...       1     False
# 39   Very poor and disappointing customer service o...       1     False
# ..                                                 ...     ...       ...
# 598  I was faced with multiple issues with the car ...       1     False
# 601                                                Bad       1     False
# 606  I made a booking and the car was returned at t...       1     False
# 614  Got the car and the interior smells like a mix...       1     False
# 615  I was charged for $156 for using 4hrs. I exten...       1     False
#
#        userName                                              title
# 9       lingz99                           Accused of False Charges
# 18     DYLove88        Affordable yet Dangerous Car Rental Service
# 36     Gary Tay  App crashes - need reinstall. Real Car broken,...
# 38     Enzaiizi                                        Over deduct
# 39       Dsunyo                             POOR customer service!
# ..          ...                                                ...
# 598  qwercarneg                              Horrendous CS support
# 601   Amos ouch                                          Buggy app
# 606      Ifan.Z                          Don’t trust this company!
# 614        Ohhl                        No Live Support & Poor Cars
# 615  Shagembeng             Expensive 4hrs booking charged at $156
#
# [120 rows x 7 columns]

# %%
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from gensim import corpora, models


# Define stopwords and other preprocessing steps
stop_words = set(stopwords.words('english'))
def preprocess(text):
    text = re.sub('[^a-zA-Z]', ' ', text)  # remove non-alphabetic characters
    words = text.lower().split()  # convert to lowercase and split into words
    words = [w for w in words if w not in stop_words]  # remove stopwords
    return words

# Apply preprocessing to reviews
doc_clean = [preprocess(doc) for doc in df_rating_1['review']]

# Create dictionary and corpus
dictionary = corpora.Dictionary(doc_clean)
corpus = [dictionary.doc2bow(doc) for doc in doc_clean]

# Perform LDA topic modeling
num_topics = 5  # number of topics to generate
lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=10)

# Print topics and their most frequent words
for i, topic in lda_model.show_topics(formatted=True, num_topics=num_topics, num_words=10):
    print(f'Topic {i}: {topic}')
# Out:
# 2023-02-24 11:52:51,915 [INFO] summarizer.preprocessing.cleaner - 'pattern' package not found; tag filters are not available for English
# 2023-02-24 11:52:51,937 [INFO] gensim.corpora.dictionary - adding document #0 to Dictionary(0 unique tokens: [])
# 2023-02-24 11:52:51,941 [INFO] gensim.corpora.dictionary - built Dictionary(1139 unique tokens: ['absolute', 'accused', 'alleged', 'booked', 'c']...) from 120 documents (total 3027 corpus positions)
# 2023-02-24 11:52:51,944 [INFO] gensim.models.ldamodel - using symmetric alpha at 0.2
# 2023-02-24 11:52:51,945 [INFO] gensim.models.ldamodel - using symmetric eta at 0.2
# 2023-02-24 11:52:51,947 [INFO] gensim.models.ldamodel - using serial LDA version on this node
# 2023-02-24 11:52:51,974 [INFO] gensim.models.ldamodel - running online (multi-pass) LDA training, 5 topics, 10 passes over the supplied corpus of 120 documents, updating model once every 120 documents, evaluating perplexity every 120 documents, iterating 50x with a convergence threshold of 0.001000
# 2023-02-24 11:52:52,053 [INFO] gensim.models.ldamodel - -8.943 per-word bound, 492.1 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,053 [INFO] gensim.models.ldamodel - PROGRESS: pass 0, at document #120/120
# 2023-02-24 11:52:52,126 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.019*"car" + 0.018*"app" + 0.007*"getgo" + 0.007*"something" + 0.007*"booking" + 0.006*"rent" + 0.006*"rental" + 0.006*"keeps" + 0.006*"error" + 0.005*"time"
# 2023-02-24 11:52:52,127 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.024*"app" + 0.017*"car" + 0.016*"book" + 0.011*"getgo" + 0.010*"even" + 0.009*"time" + 0.007*"get" + 0.007*"able" + 0.007*"screen" + 0.007*"cars"
# 2023-02-24 11:52:52,128 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.027*"app" + 0.011*"time" + 0.009*"booking" + 0.009*"keep" + 0.006*"look" + 0.006*"even" + 0.006*"get" + 0.006*"use" + 0.006*"car" + 0.005*"page"
# 2023-02-24 11:52:52,129 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.016*"getgo" + 0.016*"app" + 0.013*"car" + 0.011*"using" + 0.008*"work" + 0.008*"booking" + 0.007*"trying" + 0.006*"even" + 0.006*"use" + 0.006*"book"
# 2023-02-24 11:52:52,130 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.036*"car" + 0.021*"getgo" + 0.010*"booking" + 0.010*"app" + 0.008*"using" + 0.008*"book" + 0.007*"number" + 0.007*"service" + 0.006*"live" + 0.006*"chat"
# 2023-02-24 11:52:52,133 [INFO] gensim.models.ldamodel - topic diff=2.221958, rho=1.000000
# 2023-02-24 11:52:52,195 [INFO] gensim.models.ldamodel - -7.292 per-word bound, 156.8 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,196 [INFO] gensim.models.ldamodel - PROGRESS: pass 1, at document #120/120
# 2023-02-24 11:52:52,223 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.020*"app" + 0.014*"car" + 0.009*"something" + 0.009*"error" + 0.008*"keeps" + 0.008*"booking" + 0.006*"rental" + 0.006*"wrong" + 0.006*"went" + 0.006*"rent"
# 2023-02-24 11:52:52,223 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.024*"app" + 0.018*"car" + 0.016*"book" + 0.012*"getgo" + 0.009*"even" + 0.009*"time" + 0.008*"able" + 0.007*"get" + 0.007*"screen" + 0.006*"cars"
# 2023-02-24 11:52:52,224 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.028*"app" + 0.013*"time" + 0.009*"keep" + 0.009*"booking" + 0.007*"even" + 0.006*"look" + 0.006*"get" + 0.006*"use" + 0.006*"cannot" + 0.006*"need"
# 2023-02-24 11:52:52,227 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.016*"app" + 0.012*"getgo" + 0.012*"using" + 0.012*"car" + 0.011*"work" + 0.011*"booking" + 0.008*"bad" + 0.007*"trying" + 0.007*"book" + 0.006*"customer"
# 2023-02-24 11:52:52,231 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.035*"car" + 0.023*"getgo" + 0.010*"app" + 0.009*"booking" + 0.009*"number" + 0.008*"using" + 0.007*"book" + 0.007*"service" + 0.006*"customer" + 0.006*"use"
# 2023-02-24 11:52:52,231 [INFO] gensim.models.ldamodel - topic diff=0.448587, rho=0.577350
# 2023-02-24 11:52:52,277 [INFO] gensim.models.ldamodel - -7.131 per-word bound, 140.1 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,278 [INFO] gensim.models.ldamodel - PROGRESS: pass 2, at document #120/120
# 2023-02-24 11:52:52,301 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.022*"app" + 0.011*"car" + 0.010*"something" + 0.010*"error" + 0.009*"keeps" + 0.007*"booking" + 0.007*"wrong" + 0.006*"went" + 0.006*"showing" + 0.006*"update"
# 2023-02-24 11:52:52,302 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.023*"app" + 0.019*"car" + 0.016*"book" + 0.014*"getgo" + 0.009*"able" + 0.009*"time" + 0.009*"even" + 0.007*"get" + 0.007*"please" + 0.006*"screen"
# 2023-02-24 11:52:52,303 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.028*"app" + 0.013*"time" + 0.009*"keep" + 0.008*"booking" + 0.008*"even" + 0.006*"look" + 0.006*"get" + 0.006*"use" + 0.006*"cannot" + 0.006*"need"
# 2023-02-24 11:52:52,303 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.015*"app" + 0.012*"using" + 0.012*"work" + 0.012*"booking" + 0.011*"getgo" + 0.011*"car" + 0.009*"bad" + 0.008*"trying" + 0.007*"book" + 0.007*"customer"
# 2023-02-24 11:52:52,304 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.035*"car" + 0.022*"getgo" + 0.010*"app" + 0.009*"number" + 0.009*"booking" + 0.008*"using" + 0.007*"book" + 0.007*"service" + 0.006*"driving" + 0.006*"customer"
# 2023-02-24 11:52:52,305 [INFO] gensim.models.ldamodel - topic diff=0.265077, rho=0.500000
# 2023-02-24 11:52:52,359 [INFO] gensim.models.ldamodel - -7.075 per-word bound, 134.8 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,359 [INFO] gensim.models.ldamodel - PROGRESS: pass 3, at document #120/120
# 2023-02-24 11:52:52,386 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.023*"app" + 0.012*"error" + 0.011*"something" + 0.011*"keeps" + 0.009*"car" + 0.008*"booking" + 0.007*"went" + 0.007*"wrong" + 0.007*"showing" + 0.007*"update"
# 2023-02-24 11:52:52,387 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.023*"app" + 0.020*"car" + 0.016*"getgo" + 0.016*"book" + 0.010*"able" + 0.009*"time" + 0.008*"even" + 0.007*"please" + 0.007*"get" + 0.006*"screen"
# 2023-02-24 11:52:52,387 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.028*"app" + 0.013*"time" + 0.009*"keep" + 0.008*"booking" + 0.008*"even" + 0.007*"tried" + 0.006*"look" + 0.006*"get" + 0.006*"use" + 0.006*"cannot"
# 2023-02-24 11:52:52,389 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.015*"app" + 0.012*"using" + 0.012*"work" + 0.012*"booking" + 0.011*"getgo" + 0.011*"car" + 0.009*"bad" + 0.008*"trying" + 0.007*"book" + 0.007*"customer"
# 2023-02-24 11:52:52,390 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.035*"car" + 0.022*"getgo" + 0.010*"app" + 0.010*"number" + 0.009*"booking" + 0.008*"using" + 0.007*"book" + 0.007*"service" + 0.007*"driving" + 0.006*"customer"
# 2023-02-24 11:52:52,391 [INFO] gensim.models.ldamodel - topic diff=0.161321, rho=0.447214
# 2023-02-24 11:52:52,443 [INFO] gensim.models.ldamodel - -7.050 per-word bound, 132.5 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,444 [INFO] gensim.models.ldamodel - PROGRESS: pass 4, at document #120/120
# 2023-02-24 11:52:52,474 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.023*"app" + 0.013*"error" + 0.013*"something" + 0.012*"keeps" + 0.008*"car" + 0.008*"went" + 0.008*"wrong" + 0.008*"booking" + 0.007*"showing" + 0.007*"update"
# 2023-02-24 11:52:52,476 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.023*"app" + 0.021*"car" + 0.017*"getgo" + 0.015*"book" + 0.010*"able" + 0.009*"time" + 0.008*"even" + 0.008*"please" + 0.007*"get" + 0.006*"screen"
# 2023-02-24 11:52:52,478 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.028*"app" + 0.013*"time" + 0.010*"keep" + 0.008*"even" + 0.008*"booking" + 0.007*"tried" + 0.006*"look" + 0.006*"get" + 0.006*"use" + 0.006*"many"
# 2023-02-24 11:52:52,480 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.015*"app" + 0.012*"using" + 0.012*"work" + 0.012*"booking" + 0.011*"getgo" + 0.010*"car" + 0.010*"bad" + 0.008*"trying" + 0.008*"book" + 0.007*"customer"
# 2023-02-24 11:52:52,482 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.035*"car" + 0.021*"getgo" + 0.010*"number" + 0.010*"app" + 0.008*"booking" + 0.008*"using" + 0.007*"book" + 0.007*"service" + 0.007*"driving" + 0.006*"customer"
# 2023-02-24 11:52:52,484 [INFO] gensim.models.ldamodel - topic diff=0.098869, rho=0.408248
# 2023-02-24 11:52:52,524 [INFO] gensim.models.ldamodel - -7.039 per-word bound, 131.5 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,525 [INFO] gensim.models.ldamodel - PROGRESS: pass 5, at document #120/120
# 2023-02-24 11:52:52,554 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.024*"app" + 0.014*"error" + 0.013*"something" + 0.012*"keeps" + 0.009*"wrong" + 0.008*"went" + 0.008*"car" + 0.008*"booking" + 0.007*"showing" + 0.007*"update"
# 2023-02-24 11:52:52,555 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.023*"app" + 0.021*"car" + 0.017*"getgo" + 0.015*"book" + 0.010*"able" + 0.009*"time" + 0.008*"even" + 0.008*"please" + 0.007*"get" + 0.006*"screen"
# 2023-02-24 11:52:52,555 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.028*"app" + 0.013*"time" + 0.010*"keep" + 0.008*"tried" + 0.008*"even" + 0.007*"booking" + 0.007*"many" + 0.006*"error" + 0.006*"look" + 0.006*"get"
# 2023-02-24 11:52:52,556 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.015*"app" + 0.013*"using" + 0.012*"work" + 0.012*"booking" + 0.010*"getgo" + 0.010*"car" + 0.010*"bad" + 0.008*"trying" + 0.008*"book" + 0.008*"customer"
# 2023-02-24 11:52:52,559 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.035*"car" + 0.021*"getgo" + 0.010*"number" + 0.010*"app" + 0.008*"booking" + 0.008*"using" + 0.007*"book" + 0.007*"service" + 0.007*"driving" + 0.006*"customer"
# 2023-02-24 11:52:52,562 [INFO] gensim.models.ldamodel - topic diff=0.061164, rho=0.377964
# 2023-02-24 11:52:52,612 [INFO] gensim.models.ldamodel - -7.034 per-word bound, 131.1 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,612 [INFO] gensim.models.ldamodel - PROGRESS: pass 6, at document #120/120
# 2023-02-24 11:52:52,651 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.024*"app" + 0.014*"error" + 0.014*"something" + 0.013*"keeps" + 0.009*"wrong" + 0.009*"went" + 0.008*"booking" + 0.008*"car" + 0.007*"showing" + 0.007*"update"
# 2023-02-24 11:52:52,652 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.022*"app" + 0.021*"car" + 0.018*"getgo" + 0.015*"book" + 0.010*"able" + 0.009*"time" + 0.008*"even" + 0.008*"please" + 0.007*"get" + 0.006*"screen"
# 2023-02-24 11:52:52,652 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.028*"app" + 0.013*"time" + 0.010*"keep" + 0.009*"tried" + 0.008*"many" + 0.008*"even" + 0.007*"booking" + 0.007*"error" + 0.006*"look" + 0.006*"get"
# 2023-02-24 11:52:52,654 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.015*"app" + 0.013*"using" + 0.012*"work" + 0.012*"booking" + 0.010*"getgo" + 0.010*"car" + 0.010*"bad" + 0.008*"trying" + 0.008*"book" + 0.008*"customer"
# 2023-02-24 11:52:52,655 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.035*"car" + 0.021*"getgo" + 0.010*"number" + 0.010*"app" + 0.008*"booking" + 0.008*"using" + 0.007*"book" + 0.007*"service" + 0.007*"driving" + 0.006*"customer"
# 2023-02-24 11:52:52,656 [INFO] gensim.models.ldamodel - topic diff=0.039024, rho=0.353553
# 2023-02-24 11:52:52,706 [INFO] gensim.models.ldamodel - -7.032 per-word bound, 130.8 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,706 [INFO] gensim.models.ldamodel - PROGRESS: pass 7, at document #120/120
# 2023-02-24 11:52:52,729 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.024*"app" + 0.015*"error" + 0.015*"something" + 0.013*"keeps" + 0.009*"wrong" + 0.009*"went" + 0.008*"booking" + 0.007*"car" + 0.007*"update" + 0.007*"showing"
# 2023-02-24 11:52:52,730 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.022*"app" + 0.021*"car" + 0.018*"getgo" + 0.015*"book" + 0.010*"able" + 0.009*"time" + 0.008*"even" + 0.008*"please" + 0.007*"get" + 0.006*"screen"
# 2023-02-24 11:52:52,731 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.028*"app" + 0.013*"time" + 0.010*"keep" + 0.009*"tried" + 0.009*"many" + 0.008*"even" + 0.007*"booking" + 0.007*"times" + 0.007*"error" + 0.006*"look"
# 2023-02-24 11:52:52,733 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.015*"app" + 0.013*"using" + 0.012*"work" + 0.012*"booking" + 0.010*"getgo" + 0.010*"car" + 0.010*"bad" + 0.008*"trying" + 0.008*"book" + 0.008*"customer"
# 2023-02-24 11:52:52,734 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.035*"car" + 0.021*"getgo" + 0.010*"number" + 0.010*"app" + 0.008*"booking" + 0.007*"using" + 0.007*"book" + 0.007*"service" + 0.007*"driving" + 0.006*"customer"
# 2023-02-24 11:52:52,735 [INFO] gensim.models.ldamodel - topic diff=0.025881, rho=0.333333
# 2023-02-24 11:52:52,777 [INFO] gensim.models.ldamodel - -7.030 per-word bound, 130.7 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,777 [INFO] gensim.models.ldamodel - PROGRESS: pass 8, at document #120/120
# 2023-02-24 11:52:52,801 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.025*"app" + 0.015*"something" + 0.015*"error" + 0.013*"keeps" + 0.010*"wrong" + 0.009*"went" + 0.008*"booking" + 0.007*"car" + 0.007*"update" + 0.007*"showing"
# 2023-02-24 11:52:52,801 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.022*"app" + 0.022*"car" + 0.018*"getgo" + 0.015*"book" + 0.010*"able" + 0.009*"time" + 0.008*"even" + 0.008*"please" + 0.007*"get" + 0.006*"screen"
# 2023-02-24 11:52:52,802 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.028*"app" + 0.013*"time" + 0.010*"keep" + 0.009*"tried" + 0.009*"many" + 0.008*"even" + 0.007*"times" + 0.007*"booking" + 0.007*"error" + 0.006*"look"
# 2023-02-24 11:52:52,804 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.015*"app" + 0.013*"using" + 0.013*"work" + 0.013*"booking" + 0.010*"getgo" + 0.010*"car" + 0.010*"bad" + 0.008*"trying" + 0.008*"book" + 0.008*"customer"
# 2023-02-24 11:52:52,805 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.035*"car" + 0.021*"getgo" + 0.010*"number" + 0.010*"app" + 0.008*"booking" + 0.007*"using" + 0.007*"book" + 0.007*"service" + 0.007*"driving" + 0.006*"customer"
# 2023-02-24 11:52:52,806 [INFO] gensim.models.ldamodel - topic diff=0.017085, rho=0.316228
# 2023-02-24 11:52:52,853 [INFO] gensim.models.ldamodel - -7.029 per-word bound, 130.6 perplexity estimate based on a held-out corpus of 120 documents with 3027 words
# 2023-02-24 11:52:52,853 [INFO] gensim.models.ldamodel - PROGRESS: pass 9, at document #120/120
# 2023-02-24 11:52:52,884 [INFO] gensim.models.ldamodel - topic #0 (0.200): 0.025*"app" + 0.015*"something" + 0.015*"error" + 0.013*"keeps" + 0.010*"wrong" + 0.009*"went" + 0.008*"booking" + 0.007*"car" + 0.007*"update" + 0.007*"show"
# 2023-02-24 11:52:52,885 [INFO] gensim.models.ldamodel - topic #1 (0.200): 0.022*"app" + 0.022*"car" + 0.018*"getgo" + 0.015*"book" + 0.010*"able" + 0.009*"time" + 0.008*"even" + 0.008*"please" + 0.007*"get" + 0.006*"booking"
# 2023-02-24 11:52:52,886 [INFO] gensim.models.ldamodel - topic #2 (0.200): 0.028*"app" + 0.013*"time" + 0.009*"keep" + 0.009*"tried" + 0.009*"many" + 0.008*"even" + 0.008*"times" + 0.007*"error" + 0.007*"booking" + 0.006*"need"
# 2023-02-24 11:52:52,887 [INFO] gensim.models.ldamodel - topic #3 (0.200): 0.015*"app" + 0.013*"using" + 0.013*"work" + 0.013*"booking" + 0.010*"getgo" + 0.010*"car" + 0.010*"bad" + 0.008*"trying" + 0.008*"book" + 0.008*"customer"
# 2023-02-24 11:52:52,894 [INFO] gensim.models.ldamodel - topic #4 (0.200): 0.035*"car" + 0.021*"getgo" + 0.010*"number" + 0.009*"app" + 0.008*"booking" + 0.007*"using" + 0.007*"service" + 0.007*"book" + 0.007*"driving" + 0.006*"customer"
# 2023-02-24 11:52:52,896 [INFO] gensim.models.ldamodel - topic diff=0.012224, rho=0.301511
# Topic 0: 0.025*"app" + 0.015*"something" + 0.015*"error" + 0.013*"keeps" + 0.010*"wrong" + 0.009*"went" + 0.008*"booking" + 0.007*"car" + 0.007*"update" + 0.007*"show"
# Topic 1: 0.022*"app" + 0.022*"car" + 0.018*"getgo" + 0.015*"book" + 0.010*"able" + 0.009*"time" + 0.008*"even" + 0.008*"please" + 0.007*"get" + 0.006*"booking"
# Topic 2: 0.028*"app" + 0.013*"time" + 0.009*"keep" + 0.009*"tried" + 0.009*"many" + 0.008*"even" + 0.008*"times" + 0.007*"error" + 0.007*"booking" + 0.006*"need"
# Topic 3: 0.015*"app" + 0.013*"using" + 0.013*"work" + 0.013*"booking" + 0.010*"getgo" + 0.010*"car" + 0.010*"bad" + 0.008*"trying" + 0.008*"book" + 0.008*"customer"
# Topic 4: 0.035*"car" + 0.021*"getgo" + 0.010*"number" + 0.009*"app" + 0.008*"booking" + 0.007*"using" + 0.007*"service" + 0.007*"book" + 0.007*"driving" + 0.006*"customer"

# %%
# count the number of reviews and responses
num_reviews = len(getgodf2)
num_responses = len(getgodf2.dropna(subset=['developerResponse']))

# calculate the rate of response
response_rate = num_responses / num_reviews

# print the response rate
print(f'The response rate is {response_rate:.2%}')
# Out:
# The response rate is 49.35%

# %%
# count the number of reviews and responses for rating 1
num_reviews = len(df_rating_1)
num_responses = len(df_rating_1.dropna(subset=['developerResponse']))

# calculate the rate of response
response_rate = num_responses / num_reviews

# print the response rate
print(f'The response rate is {response_rate:.2%}')
# Out:
# The response rate is 60.83%

# %%
# Convert the date column to a datetime object
getgodf2['date'] = pd.to_datetime(getgodf2['date'])

# Group the dataframe by month and count the number of responses
responses_per_month = getgodf2.groupby(pd.Grouper(key='date', freq='M'))['developerResponse'].count()

# Group the dataframe by month and count the total number of reviews
total_reviews_per_month = getgodf2.groupby(pd.Grouper(key='date', freq='M'))['review'].count()

# Calculate the response rate for each month
response_rate = responses_per_month / total_reviews_per_month

# Plot the response rate over time
response_rate.plot(kind='line')

# Add labels and title to the plot
plt.xlabel('Month')
plt.ylabel('Response Rate')
plt.title('Developer Response Rate by Month')
plt.show()
